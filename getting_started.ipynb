# %% [markdown]
# <a href="https://colab.research.google.com/github/Dyex719/colab_experiments/blob/master/getting_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Make sure you do:
# Google Colab Toolbar > RunTime > Change runtime type> Set Hardware Accelerator> GPU

# !pip3 install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 41kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=1b68e3c46d5c162a49fabd072510aa8687d6d053185fddfc5a6ec450a43161ba
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
# Get Data from Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Can use relative path from /content/drive/My Drive/Colab_Data
import os
os.chdir("/content/drive/My Drive/Colab_Data")
# !ls
# Out:
# scientists.jpg

# %%
from IPython.display import Image 
full_img = Image(filename='scientists.jpg')
display(full_img)

# %%
# %matplotlib inline

# %%
from IPython.display import Image

# %%
from PIL import Image
import face_recognition

# Load the jpg file into a numpy array
image = face_recognition.load_image_file("scientists.jpg")
face_locations = face_recognition.face_locations(image, model="cnn")

print("I found {} face(s) in this photograph.".format(len(face_locations)))

for face_location in face_locations:

    # Print the location of each face in this image
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # You can access the actual face itself like this:
    face_image = image[top:bottom, left:right]
    pil_image = Image.fromarray(face_image)
    display(pil_image)
# Out:
# I found 29 face(s) in this photograph.
# A face is located at pixel location Top: 465, Left: 217, Bottom: 505, Right: 256
# <PIL.Image.Image image mode=RGB size=39x40 at 0x7FD1F2BEA7B8>
# A face is located at pixel location Top: 457, Left: 629, Bottom: 497, Right: 668
# <PIL.Image.Image image mode=RGB size=39x40 at 0x7FD1F2BEA198>
# A face is located at pixel location Top: 417, Left: 281, Bottom: 457, Right: 320
# <PIL.Image.Image image mode=RGB size=39x40 at 0x7FD1F2BEA8D0>
# A face is located at pixel location Top: 465, Left: 977, Bottom: 505, Right: 1016
# <PIL.Image.Image image mode=RGB size=39x40 at 0x7FD1F2BEA940>
# A face is located at pixel location Top: 433, Left: 161, Bottom: 473, Right: 200
# <PIL.Image.Image image mode=RGB size=39x40 at 0x7FD1F2BEA898>
# A face is located at pixel location Top: 337, Left: 633, Bottom: 377, Right: 672
# <PIL.Image.Image image mode=RGB size=39x40 at 0x7FD1F2BEAAC8>
# ...
